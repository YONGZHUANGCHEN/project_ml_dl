# %%
import pandas as pd
import numpy as np

# %%
#Read data set
final=pd.read_csv("ori_data.csv")

# %%
final
# Out:
#       Unnamed: 0  Sentence ID                          HIT ID  Formality  \
# 0              0            0  3D1TUISJWHZ3X38ICFUZ8CHJC9KIUW        5.8
# 1              1            1  3GKAWYFRAOS9XNK03FUU79E7CNKDPT        5.2
# 2              2            2  3VMHWJRYHUFB4G0NGCZ1PM3VQZ8XFB        5.2
# 3              3            3  3NFWQRSHVDD0IU5XR2ZX1030N9CFG1        4.8
# 4              4            4  359AP8GAGFJAMPAM7X52NH54RT17CF        5.6
# ...          ...          ...                             ...        ...
# 7031        7031         7018  3THR0FZ95OSAAZWR1WF31MHMBS2OLH        5.2
# 7032        7032         7019  3CVBMEMMXAF13XL2TPJ3Y82K4MK7H4        4.8
# 7033        7033         7020  3538U0YQ1ETZOIT9WNSDI6ERJ5LF39        4.8
# 7034        7034         7022  3XH7ZM9YX1TI6ANY4RTHQ8VWML69RF        4.4
# 7035        7035         7023  3FULMHZ7OTWQCO4UIO19N1Q6U6T4MQ        5.6
#
#       Informativeness  Implicature  Length in Words  Length in Characters  \
# 0                 6.4          4.2               33                   201
# 1                 5.8          2.6               45                   266
# 2                 5.6          4.8               29                   186
# 3                 4.4          3.0               16                    98
# 4                 5.2          2.8               19                   108
# ...               ...          ...              ...                   ...
# 7031              6.0          4.4               19                   118
# 7032              5.6          3.6               52                   294
# 7033              5.2          3.2               22                   130
# 7034              4.6          4.2               29                   195
# 7035              5.6          4.6               22                   127
#
#         F-score   I-score  Lexical Density  \
# 0     93.939394  7.242424        66.666667
# 1     85.555556  5.200000        62.222222
# 2     93.103448  3.896552        65.517241
# 3     87.500000  3.375000        68.750000
# 4     84.210526  6.210526        63.157895
# ...         ...       ...              ...
# 7031  63.157895  5.842105        57.894737
# 7032  81.730769  4.076923        61.538462
# 7033  68.181818  5.409091        81.818182
# 7034  74.137931  6.310345        68.965517
# 7035  75.000000  6.000000        63.636364
#
#                                                Sentence  Label
# 0     10In High Bay 4 of the Vehicle Assembly Buildi...      1
# 1     12The oxygen vent arm and hood removed from th...      1
# 2     13In the Rotation, Processing and Surge Facili...      1
# 3     14In the Vehicle Assembly Building's High Bay ...      1
# 4     15In the Vehicle Assembly Building's High Bay ...      1
# ...                                                 ...    ...
# 7031  Yuan's revelations cover only the bidding proc...      0
# 7032  Yuan Weimin was the toast of China's sporting ...      0
# 7033  Yu Jingyuan said Qian had very deep understand...      0
# 7034  Zelaya, a timber tycoon whose turn to the poli...      0
# 7035  Zelaya's removal from office has been viewed w...      0
#
# [7036 rows x 13 columns]

# %%
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from time import time
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from itertools import product 
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, neural_network
import warnings
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
#ngram_range parameter array
ngramV=[1,2,3]
#ngram_range and binary parameter combination array
boolV=[True,False]
v=list(product(ngramV,boolV))

# %%
#Classification algorithm array
MLA = [
    LogisticRegression(),
    naive_bayes.MultinomialNB(),
    ensemble.RandomForestClassifier(),
    SVC(),
]

# %%
TF = []
tf = pd.DataFrame(columns = TF)
row_index=0
for i in ngramV:
    #Construct the constructor of TfidfVectorizer and set the parameters
    TFIDF = TfidfVectorizer(stop_words='english',lowercase=True,ngram_range=(1,i))
    #Use TfidfVectorizer to process data
    features = TFIDF.fit_transform(final.Sentence)
    label = final.Label.astype('int')
    #Divide the test set and training set
    X_train, X_test, y_train, y_test = train_test_split(features,label, random_state = 0)
    for model in MLA:
        print("Ngram{0},model{1}".format(i,model))
        model.fit(X_train,y_train)
        pred = model.predict(X_test)
        name=str(model).split("(")[0]+"_tf_ng_"+str(i)
        tf.loc[row_index,'Model'] = name
        tf.loc[row_index,'Precision'] = metrics.precision_score(y_test,pred)
        tf.loc[row_index,'F1-Score']= metrics.f1_score(y_test,pred)
        tf.loc[row_index,'Recall']= metrics.recall_score(y_test,pred)
        tf.loc[row_index,'Accuracy']= metrics.accuracy_score(y_test,pred)
        row_index += 1
# Out:
# Ngram1,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Ngram1,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# Ngram1,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Ngram1,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# Ngram2,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Ngram2,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# Ngram2,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Ngram2,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# Ngram3,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Ngram3,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# Ngram3,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Ngram3,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
Count = []
count_data = pd.DataFrame(columns = Count)
row_index=0
for i in v:
    #Construct the constructor of CountVectorizer and set the parameters
    count = CountVectorizer(stop_words='english',lowercase=True,ngram_range=(1,i[0]),binary = i[1])
    ##Use CountVectorizer to process data
    features_count = count.fit_transform(final.Sentence)
    label = final.Label.astype('int')
    #Divide the test set and training set
    X_train, X_test, y_train, y_test = train_test_split(features_count,label, random_state = 0)
    for model in MLA:
        name=str(model).split("(")[0]+"_count_ng_"+str(i)
        print("ngram{0[0]},binary{0[1]},model{1}".format(i,model))
        model.fit(X_train,y_train)
        pred = model.predict(X_test)
        count_data.loc[row_index,'Model'] = name
        count_data.loc[row_index,'Precision'] = metrics.precision_score(y_test,pred)
        count_data.loc[row_index,'F1-Score']= metrics.f1_score(y_test,pred)
        count_data.loc[row_index,'Recall']= metrics.recall_score(y_test,pred)
        count_data.loc[row_index,'Accuracy']= metrics.accuracy_score(y_test,pred)
        row_index += 1
# Out:
# ngram1,binaryTrue,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram1,binaryTrue,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram1,binaryTrue,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram1,binaryTrue,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram1,binaryFalse,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram1,binaryFalse,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram1,binaryFalse,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram1,binaryFalse,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram2,binaryTrue,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram2,binaryTrue,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram2,binaryTrue,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram2,binaryTrue,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram2,binaryFalse,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram2,binaryFalse,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram2,binaryFalse,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram2,binaryFalse,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram3,binaryTrue,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram3,binaryTrue,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram3,binaryTrue,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram3,binaryTrue,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram3,binaryFalse,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram3,binaryFalse,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram3,binaryFalse,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram3,binaryFalse,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
tf
# Out:
#                              Model  Precision  F1-Score    Recall  Accuracy
# 0       LogisticRegression_tf_ng_1   0.804207  0.871548  0.951196  0.833428
# 1            MultinomialNB_tf_ng_1   0.847603  0.894713  0.947368  0.867538
# 2   RandomForestClassifier_tf_ng_1   0.829565  0.869248  0.912919  0.836839
# 3                      SVC_tf_ng_1   0.839226  0.892969  0.954067  0.864127
# 4       LogisticRegression_tf_ng_2   0.756857  0.852966  0.977033  0.799886
# 5            MultinomialNB_tf_ng_2   0.773173  0.865093  0.981818  0.818078
# 6   RandomForestClassifier_tf_ng_2   0.810189  0.871795  0.943541  0.835134
# 7                      SVC_tf_ng_2   0.778544  0.864681  0.972249  0.819215
# 8       LogisticRegression_tf_ng_3   0.717573  0.830173  0.984689  0.760659
# 9            MultinomialNB_tf_ng_3   0.727145  0.838265  0.989474  0.773167
# 10  RandomForestClassifier_tf_ng_3   0.786898  0.862457  0.954067  0.819215
# 11                     SVC_tf_ng_3   0.736011  0.841328  0.981818  0.779989

# %%
count_data
# Out:
#                                          Model  Precision  F1-Score    Recall  \
# 0        LogisticRegression_count_ng_(1, True)   0.856028  0.898089  0.944498
# 1             MultinomialNB_count_ng_(1, True)   0.907425  0.903939  0.900478
# 2    RandomForestClassifier_count_ng_(1, True)   0.844465  0.863424  0.883254
# 3                       SVC_count_ng_(1, True)   0.837984  0.863636  0.890909
# 4       LogisticRegression_count_ng_(1, False)   0.853933  0.897366  0.945455
# 5            MultinomialNB_count_ng_(1, False)   0.908301  0.904373  0.900478
# 6   RandomForestClassifier_count_ng_(1, False)   0.836771  0.863889  0.892823
# 7                      SVC_count_ng_(1, False)   0.833631  0.861766  0.891866
# 8        LogisticRegression_count_ng_(2, True)   0.829698  0.884220  0.946411
# 9             MultinomialNB_count_ng_(2, True)   0.910134  0.910569  0.911005
# 10   RandomForestClassifier_count_ng_(2, True)   0.808333  0.864143  0.928230
# 11                      SVC_count_ng_(2, True)   0.814815  0.848095  0.884211
# 12      LogisticRegression_count_ng_(2, False)   0.825688  0.882353  0.947368
# 13           MultinomialNB_count_ng_(2, False)   0.914894  0.910053  0.905263
# 14  RandomForestClassifier_count_ng_(2, False)   0.818565  0.869955  0.928230
# 15                     SVC_count_ng_(2, False)   0.813995  0.845446  0.879426
# 16       LogisticRegression_count_ng_(3, True)   0.810767  0.875385  0.951196
# 17            MultinomialNB_count_ng_(3, True)   0.906933  0.910391  0.913876
# 18   RandomForestClassifier_count_ng_(3, True)   0.801146  0.863697  0.936842
# 19                      SVC_count_ng_(3, True)   0.799826  0.837739  0.879426
# 20      LogisticRegression_count_ng_(3, False)   0.810966  0.874283  0.948325
# 21           MultinomialNB_count_ng_(3, False)   0.909875  0.909004  0.908134
# 22  RandomForestClassifier_count_ng_(3, False)   0.795620  0.861282  0.938756
# 23                     SVC_count_ng_(3, False)   0.799475  0.834934  0.873684
#
#     Accuracy
# 0   0.872655
# 1   0.886299
# 2   0.833997
# 3   0.832860
# 4   0.871518
# 5   0.886868
# 6   0.832860
# 7   0.830017
# 8   0.852757
# 9   0.893690
# 10  0.826606
# 11  0.811825
# 12  0.849915
# 13  0.893690
# 14  0.835134
# 15  0.808982
# 16  0.839113
# 17  0.893121
# 18  0.824332
# 19  0.797612
# 20  0.837976
# 21  0.891984
# 22  0.820352
# 23  0.794770

# %%
aa=pd.concat([tf,count_data],ignore_index=True)

# %%
aa
# Out:
#                                          Model  Precision  F1-Score    Recall  \
# 0                   LogisticRegression_tf_ng_1   0.804207  0.871548  0.951196
# 1                        MultinomialNB_tf_ng_1   0.847603  0.894713  0.947368
# 2               RandomForestClassifier_tf_ng_1   0.829565  0.869248  0.912919
# 3                                  SVC_tf_ng_1   0.839226  0.892969  0.954067
# 4                   LogisticRegression_tf_ng_2   0.756857  0.852966  0.977033
# 5                        MultinomialNB_tf_ng_2   0.773173  0.865093  0.981818
# 6               RandomForestClassifier_tf_ng_2   0.810189  0.871795  0.943541
# 7                                  SVC_tf_ng_2   0.778544  0.864681  0.972249
# 8                   LogisticRegression_tf_ng_3   0.717573  0.830173  0.984689
# 9                        MultinomialNB_tf_ng_3   0.727145  0.838265  0.989474
# 10              RandomForestClassifier_tf_ng_3   0.786898  0.862457  0.954067
# 11                                 SVC_tf_ng_3   0.736011  0.841328  0.981818
# 12       LogisticRegression_count_ng_(1, True)   0.856028  0.898089  0.944498
# 13            MultinomialNB_count_ng_(1, True)   0.907425  0.903939  0.900478
# 14   RandomForestClassifier_count_ng_(1, True)   0.844465  0.863424  0.883254
# 15                      SVC_count_ng_(1, True)   0.837984  0.863636  0.890909
# 16      LogisticRegression_count_ng_(1, False)   0.853933  0.897366  0.945455
# 17           MultinomialNB_count_ng_(1, False)   0.908301  0.904373  0.900478
# 18  RandomForestClassifier_count_ng_(1, False)   0.836771  0.863889  0.892823
# 19                     SVC_count_ng_(1, False)   0.833631  0.861766  0.891866
# 20       LogisticRegression_count_ng_(2, True)   0.829698  0.884220  0.946411
# 21            MultinomialNB_count_ng_(2, True)   0.910134  0.910569  0.911005
# 22   RandomForestClassifier_count_ng_(2, True)   0.808333  0.864143  0.928230
# 23                      SVC_count_ng_(2, True)   0.814815  0.848095  0.884211
# 24      LogisticRegression_count_ng_(2, False)   0.825688  0.882353  0.947368
# 25           MultinomialNB_count_ng_(2, False)   0.914894  0.910053  0.905263
# 26  RandomForestClassifier_count_ng_(2, False)   0.818565  0.869955  0.928230
# 27                     SVC_count_ng_(2, False)   0.813995  0.845446  0.879426
# 28       LogisticRegression_count_ng_(3, True)   0.810767  0.875385  0.951196
# 29            MultinomialNB_count_ng_(3, True)   0.906933  0.910391  0.913876
# 30   RandomForestClassifier_count_ng_(3, True)   0.801146  0.863697  0.936842
# 31                      SVC_count_ng_(3, True)   0.799826  0.837739  0.879426
# 32      LogisticRegression_count_ng_(3, False)   0.810966  0.874283  0.948325
# 33           MultinomialNB_count_ng_(3, False)   0.909875  0.909004  0.908134
# 34  RandomForestClassifier_count_ng_(3, False)   0.795620  0.861282  0.938756
# 35                     SVC_count_ng_(3, False)   0.799475  0.834934  0.873684
#
#     Accuracy
# 0   0.833428
# 1   0.867538
# 2   0.836839
# 3   0.864127
# 4   0.799886
# 5   0.818078
# 6   0.835134
# 7   0.819215
# 8   0.760659
# 9   0.773167
# 10  0.819215
# 11  0.779989
# 12  0.872655
# 13  0.886299
# 14  0.833997
# 15  0.832860
# 16  0.871518
# 17  0.886868
# 18  0.832860
# 19  0.830017
# 20  0.852757
# 21  0.893690
# 22  0.826606
# 23  0.811825
# 24  0.849915
# 25  0.893690
# 26  0.835134
# 27  0.808982
# 28  0.839113
# 29  0.893121
# 30  0.824332
# 31  0.797612
# 32  0.837976
# 33  0.891984
# 34  0.820352
# 35  0.794770
