# %%
import pandas as pd
import numpy as np

# %%
#Read data set
final=pd.read_excel("newdataset.xls")

# %%
final
# Out:
#        Unnamed: 0                                      SentimentText  Label  \
# 0           11208  #NBA lakers  hopefully game 3 will be good  cl...      1
# 1             949   Finally managed to check the Euromillions res...      1
# 2           98393  @cooloutrageous ur boy made it 2 the finals on...      1
# 3           47483  @allyheartsbb yeah, probably that is more nece...      1
# 4            6061  #inaperfectworld I would be able to dance for ...      1
# ...           ...                                                ...    ...
# 39530       19530   in the case of an apparently endless argument...      0
# 39531       19531   the cost of prolonging the row by even one mo...      0
# 39532       19532   if the rest of the party can enforce that  th...      0
# 39533       19533   but souness said he did not think beating the...      0
# 39534       19534    i think if he got it this year he would want...      0
#
#        Unnamed: 0.1
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 39530       19530.0
# 39531       19531.0
# 39532       19532.0
# 39533       19533.0
# 39534       19534.0
#
# [39535 rows x 4 columns]

# %%
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from time import time
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from itertools import product 
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, neural_network
import warnings
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %%
#ngram_range parameter array
ngramV=[1,2,3]
#ngram_range and binary parameter combination array
boolV=[True,False]
v=list(product(ngramV,boolV))

# %%
#Classification algorithm array
MLA = [
    LogisticRegression(),
    naive_bayes.MultinomialNB(),
    ensemble.RandomForestClassifier(),
    SVC(),
]

# %%
TF = []
tf = pd.DataFrame(columns = TF)
row_index=0
for i in ngramV:
    #Construct the constructor of TfidfVectorizer and set the parameters
    TFIDF = TfidfVectorizer(stop_words='english',lowercase=True,ngram_range=(1,i))
    #Use TfidfVectorizer to process data
    features = TFIDF.fit_transform(final.SentimentText)
    label = final.Label.astype('int')
    #Divide the test set and training set
    X_train, X_test, y_train, y_test = train_test_split(features,label, random_state = 0)
    for model in MLA:
        print("Ngram{0},model{1}".format(i,model))
        model.fit(X_train,y_train)
        pred = model.predict(X_test)
        name=str(model).split("(")[0]+"_tf_ng_"+str(i)
        tf.loc[row_index,'Model'] = name
        tf.loc[row_index,'Precision'] = metrics.precision_score(y_test,pred)
        tf.loc[row_index,'F1-Score']= metrics.f1_score(y_test,pred)
        tf.loc[row_index,'Recall']= metrics.recall_score(y_test,pred)
        tf.loc[row_index,'Accuracy']= metrics.accuracy_score(y_test,pred)
        row_index += 1
# Out:
# Ngram1,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Ngram1,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# Ngram1,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Ngram1,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# Ngram2,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Ngram2,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# Ngram2,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Ngram2,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# Ngram3,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# Ngram3,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# Ngram3,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# Ngram3,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
Count = []
count_data = pd.DataFrame(columns = Count)
row_index=0
for i in v:
    #Construct the constructor of CountVectorizer and set the parameters
    count = CountVectorizer(stop_words='english',lowercase=True,ngram_range=(1,i[0]),binary = i[1])
    ##Use CountVectorizer to process data
    features_count = count.fit_transform(final.SentimentText)
    label = final.Label.astype('int')
    #Divide the test set and training set
    X_train, X_test, y_train, y_test = train_test_split(features_count,label, random_state = 0)
    for model in MLA:
        name=str(model).split("(")[0]+"_count_ng_"+str(i)
        print("ngram{0[0]},binary{0[1]},model{1}".format(i,model))
        model.fit(X_train,y_train)
        pred = model.predict(X_test)
        count_data.loc[row_index,'Model'] = name
        count_data.loc[row_index,'Precision'] = metrics.precision_score(y_test,pred)
        count_data.loc[row_index,'F1-Score']= metrics.f1_score(y_test,pred)
        count_data.loc[row_index,'Recall']= metrics.recall_score(y_test,pred)
        count_data.loc[row_index,'Accuracy']= metrics.accuracy_score(y_test,pred)
        row_index += 1
# Out:
# ngram1,binaryTrue,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram1,binaryTrue,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram1,binaryTrue,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram1,binaryTrue,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram1,binaryFalse,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram1,binaryFalse,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram1,binaryFalse,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram1,binaryFalse,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram2,binaryTrue,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram2,binaryTrue,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram2,binaryTrue,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram2,binaryTrue,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram2,binaryFalse,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram2,binaryFalse,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram2,binaryFalse,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram2,binaryFalse,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram3,binaryTrue,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram3,binaryTrue,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram3,binaryTrue,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram3,binaryTrue,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# ngram3,binaryFalse,modelLogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
# ngram3,binaryFalse,modelMultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# ngram3,binaryFalse,modelRandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# ngram3,binaryFalse,modelSVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
tf
# Out:
#                              Model  Precision  F1-Score    Recall  Accuracy
# 0       LogisticRegression_tf_ng_1   0.942783  0.948646  0.954582  0.948199
# 1            MultinomialNB_tf_ng_1   0.975537  0.949974  0.925717  0.951133
# 2   RandomForestClassifier_tf_ng_1   0.904410  0.921691  0.939645  0.919972
# 3                      SVC_tf_ng_1   0.947264  0.954003  0.960840  0.953561
# 4       LogisticRegression_tf_ng_2   0.941117  0.943202  0.945297  0.942938
# 5            MultinomialNB_tf_ng_2   0.972340  0.950464  0.929552  0.951437
# 6   RandomForestClassifier_tf_ng_2   0.898902  0.927706  0.958417  0.925132
# 7                      SVC_tf_ng_2   0.942726  0.948118  0.953573  0.947693
# 8       LogisticRegression_tf_ng_3   0.938449  0.937026  0.935608  0.936969
# 9            MultinomialNB_tf_ng_3   0.968436  0.951530  0.935204  0.952246
# 10  RandomForestClassifier_tf_ng_3   0.895743  0.928745  0.964271  0.925840
# 11                     SVC_tf_ng_3   0.942725  0.944814  0.946912  0.944557

# %%
count_data
# Out:
#                                          Model  Precision  F1-Score    Recall  \
# 0        LogisticRegression_count_ng_(1, True)   0.935630  0.947379  0.959427
# 1             MultinomialNB_count_ng_(1, True)   0.969275  0.955685  0.942471
# 2    RandomForestClassifier_count_ng_(1, True)   0.903753  0.920670  0.938232
# 3                       SVC_count_ng_(1, True)   0.930918  0.940036  0.949334
# 4       LogisticRegression_count_ng_(1, False)   0.937784  0.947988  0.958417
# 5            MultinomialNB_count_ng_(1, False)   0.969269  0.955578  0.942269
# 6   RandomForestClassifier_count_ng_(1, False)   0.904873  0.922514  0.940856
# 7                      SVC_count_ng_(1, False)   0.929956  0.939249  0.948728
# 8        LogisticRegression_count_ng_(2, True)   0.931952  0.946762  0.962051
# 9             MultinomialNB_count_ng_(2, True)   0.966084  0.957328  0.948728
# 10   RandomForestClassifier_count_ng_(2, True)   0.901181  0.927494  0.955390
# 11                      SVC_count_ng_(2, True)   0.923244  0.932561  0.942067
# 12      LogisticRegression_count_ng_(2, False)   0.932094  0.946542  0.961445
# 13           MultinomialNB_count_ng_(2, False)   0.966290  0.957531  0.948930
# 14  RandomForestClassifier_count_ng_(2, False)   0.896950  0.925437  0.955793
# 15                     SVC_count_ng_(2, False)   0.924386  0.933440  0.942673
# 16       LogisticRegression_count_ng_(3, True)   0.926516  0.943949  0.962051
# 17            MultinomialNB_count_ng_(3, True)   0.958325  0.957260  0.956197
# 18   RandomForestClassifier_count_ng_(3, True)   0.891882  0.922732  0.955793
# 19                      SVC_count_ng_(3, True)   0.917808  0.925433  0.933185
# 20      LogisticRegression_count_ng_(3, False)   0.925825  0.943785  0.962455
# 21           MultinomialNB_count_ng_(3, False)   0.959473  0.957630  0.955793
# 22  RandomForestClassifier_count_ng_(3, False)   0.893401  0.925144  0.959225
# 23                     SVC_count_ng_(3, False)   0.917147  0.924402  0.931772
#
#     Accuracy
# 0   0.946580
# 1   0.956192
# 2   0.918960
# 3   0.939296
# 4   0.947289
# 5   0.956091
# 6   0.920781
# 7   0.938486
# 8   0.945771
# 9   0.957608
# 10  0.925132
# 11  0.931708
# 12  0.945569
# 13  0.957811
# 14  0.922805
# 15  0.932618
# 16  0.942736
# 17  0.957204
# 18  0.919769
# 19  0.924626
# 20  0.942533
# 21  0.957608
# 22  0.922197
# 23  0.923614

# %%
aa=pd.concat([tf,count_data],ignore_index=True)

# %%
aa
# Out:
#                                          Model  Precision  F1-Score    Recall  \
# 0                   LogisticRegression_tf_ng_1   0.942783  0.948646  0.954582
# 1                        MultinomialNB_tf_ng_1   0.975537  0.949974  0.925717
# 2               RandomForestClassifier_tf_ng_1   0.904410  0.921691  0.939645
# 3                                  SVC_tf_ng_1   0.947264  0.954003  0.960840
# 4                   LogisticRegression_tf_ng_2   0.941117  0.943202  0.945297
# 5                        MultinomialNB_tf_ng_2   0.972340  0.950464  0.929552
# 6               RandomForestClassifier_tf_ng_2   0.898902  0.927706  0.958417
# 7                                  SVC_tf_ng_2   0.942726  0.948118  0.953573
# 8                   LogisticRegression_tf_ng_3   0.938449  0.937026  0.935608
# 9                        MultinomialNB_tf_ng_3   0.968436  0.951530  0.935204
# 10              RandomForestClassifier_tf_ng_3   0.895743  0.928745  0.964271
# 11                                 SVC_tf_ng_3   0.942725  0.944814  0.946912
# 12       LogisticRegression_count_ng_(1, True)   0.935630  0.947379  0.959427
# 13            MultinomialNB_count_ng_(1, True)   0.969275  0.955685  0.942471
# 14   RandomForestClassifier_count_ng_(1, True)   0.903753  0.920670  0.938232
# 15                      SVC_count_ng_(1, True)   0.930918  0.940036  0.949334
# 16      LogisticRegression_count_ng_(1, False)   0.937784  0.947988  0.958417
# 17           MultinomialNB_count_ng_(1, False)   0.969269  0.955578  0.942269
# 18  RandomForestClassifier_count_ng_(1, False)   0.904873  0.922514  0.940856
# 19                     SVC_count_ng_(1, False)   0.929956  0.939249  0.948728
# 20       LogisticRegression_count_ng_(2, True)   0.931952  0.946762  0.962051
# 21            MultinomialNB_count_ng_(2, True)   0.966084  0.957328  0.948728
# 22   RandomForestClassifier_count_ng_(2, True)   0.901181  0.927494  0.955390
# 23                      SVC_count_ng_(2, True)   0.923244  0.932561  0.942067
# 24      LogisticRegression_count_ng_(2, False)   0.932094  0.946542  0.961445
# 25           MultinomialNB_count_ng_(2, False)   0.966290  0.957531  0.948930
# 26  RandomForestClassifier_count_ng_(2, False)   0.896950  0.925437  0.955793
# 27                     SVC_count_ng_(2, False)   0.924386  0.933440  0.942673
# 28       LogisticRegression_count_ng_(3, True)   0.926516  0.943949  0.962051
# 29            MultinomialNB_count_ng_(3, True)   0.958325  0.957260  0.956197
# 30   RandomForestClassifier_count_ng_(3, True)   0.891882  0.922732  0.955793
# 31                      SVC_count_ng_(3, True)   0.917808  0.925433  0.933185
# 32      LogisticRegression_count_ng_(3, False)   0.925825  0.943785  0.962455
# 33           MultinomialNB_count_ng_(3, False)   0.959473  0.957630  0.955793
# 34  RandomForestClassifier_count_ng_(3, False)   0.893401  0.925144  0.959225
# 35                     SVC_count_ng_(3, False)   0.917147  0.924402  0.931772
#
#     Accuracy
# 0   0.948199
# 1   0.951133
# 2   0.919972
# 3   0.953561
# 4   0.942938
# 5   0.951437
# 6   0.925132
# 7   0.947693
# 8   0.936969
# 9   0.952246
# 10  0.925840
# 11  0.944557
# 12  0.946580
# 13  0.956192
# 14  0.918960
# 15  0.939296
# 16  0.947289
# 17  0.956091
# 18  0.920781
# 19  0.938486
# 20  0.945771
# 21  0.957608
# 22  0.925132
# 23  0.931708
# 24  0.945569
# 25  0.957811
# 26  0.922805
# 27  0.932618
# 28  0.942736
# 29  0.957204
# 30  0.919769
# 31  0.924626
# 32  0.942533
# 33  0.957608
# 34  0.922197
# 35  0.923614
